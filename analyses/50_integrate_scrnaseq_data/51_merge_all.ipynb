# %%
# %load_ext autoreload
# %autoreload 2

import scanpy as sc
import numpy as np
import itertools
from tqdm import trange, tqdm
import scipy.sparse
import numpy.testing as npt
from scanpy_helpers.integration import (
    normalize_by_gene_length,
    sanitize_adata,
    validate_adata,
    add_doublet_annotation,
    undo_log_norm,
    remap_gene_symbols,
    drop_duplicated_genes,
    aggregate_duplicate_gene_symbols,
    merge_datasets,
    MANDATORY_COLS,
)
from threadpoolctl import threadpool_limits
from tqdm.contrib.concurrent import process_map
import mygene
from operator import and_
from functools import reduce
import pandas as pd
import anndata
import re

# %%
threadpool_limits(8)

# %%
sc.set_figure_params(figsize=(5, 5))

# %%
dataset_table = pd.read_csv("../../tables/samplesheet_scrnaseq_preprocessing.csv")

# %%
dataset_table
# Out:
#                                            id  \
# 0                    Adams_Kaminski_2020_COPD
# 1                       Chen_Zhang_2020_NSCLC
# 2                 Goveia_Carmeliet_2020_NSCLC
# 3                        Guo_Zhang_2018_NSCLC
# 4   Habermann_Kropski_2020_pulmonary-fibrosis
# 5                            He_Fan_2021_LUAD
# 6                           Kim_Lee_2020_LUAD
# 7                 Lambrechts_2018_LUAD_6149v1
# 8                 Lambrechts_2018_LUAD_6149v2
# 9                   Lambrechts_2018_LUAD_6653
# 10               Laughney_Massague_2020_NSCLC
# 11    Madissoon_Meyer_2020_pulmonary-fibrosis
# 12                     Maier_Merad_2020_NSCLC
# 13                  Maynard_Bivona_2020_NSCLC
# 14      Mayr_Schiller_2020_pulmonary-fibrosis
# 15   Reyfman_Misharin_2018_pulmonary-fibrosis
# 16           Travaglini_Krasnow_2020_Lung_10x
# 17           Travaglini_Krasnow_2020_Lung_SS2
# 18                                     UKIM-V
# 19               Vieira_Teichmann_2019_asthma
# 20                         Wu_Zhou_2021_NSCLC
# 21                  Zilionis_Klein_2019_NSCLC
#
#                                           input_adata  min_counts  max_counts  \
# 0   data/10_public_datasets/Adams_Kaminski_2020_CO...        1000       35000
# 1   data/10_public_datasets/Chen_Zhang_2020_NSCLC/...         600       30000
# 2   data/10_public_datasets/Goveia_Carmeliet_2020_...         600       30000
# 3   data/10_public_datasets/Guo_Zhang_2018_NSCLC/h...       20000     3000000
# 4   data/10_public_datasets/Habermann_Kropski_2020...         600       30000
# 5   data/10_public_datasets/Kim_Lee_2020_LUAD/h5ad...        1000       35000
# 6   data/10_public_datasets/He_Fan_2021_LUAD/h5ad_...         600       30000
# 7   data/10_public_datasets/Lambrechts_2018_LUAD/E...         600       30000
# 8   data/10_public_datasets/Lambrechts_2018_LUAD/E...         600       30000
# 9   data/10_public_datasets/Lambrechts_2018_LUAD/E...        1200       40000
# 10  data/10_public_datasets/Laughney_Massague_2020...        1800       40000
# 11  data/10_public_datasets/Madissoon_Meyer_2020_p...         600       30000
# 12  data/10_public_datasets/Maier_Merad_2020_NSCLC...        1000       30000
# 13  data/10_public_datasets/Maynard_Bivona_2020_NS...       20000    20000000
# 14  data/10_public_datasets/Mayr_Schiller_2020_pul...         600       30000
# 15  data/10_public_datasets/Reyfman_Misharin_2018_...        1000       30000
# 16  data/10_public_datasets/Travaglini_Krasnow_202...        1000       30000
# 17  data/10_public_datasets/Travaglini_Krasnow_202...       20000     6000000
# 18  data/11_own_datasets/batch1_3patients/h5ad_raw...        2000      100000
# 19  data/10_public_datasets/Vieira_Teichmann_2019_...         600       30000
# 20  data/10_public_datasets/Wu_Zhou_2021_NSCLC/h5a...         600       30000
# 21  data/10_public_datasets/Zilionis_Klein_2019_NS...         600       30000
#
#     min_genes  max_genes  max_pct_mito batch_key  run_solo
# 0         500      10000            20    sample      True
# 1         250      10000            20    sample      True
# 2         250      10000            20    sample      True
# 3        1000      20000            20    sample     False
# 4         200      10000            20    sample      True
# 5         300      10000            20    sample      True
# 6         250      10000            20    sample      True
# 7         200      10000            15    sample      True
# 8         250      10000            20    sample      True
# 9         250      10000            20    sample      True
# 10        500      10000            20    sample      True
# 11        300      10000            20    sample      True
# 12        400      10000            15    sample      True
# 13        600      20000            30    sample     False
# 14        250      10000            10    sample      True
# 15        250      10000            20    sample      True
# 16        500      10000             0    sample      True
# 17        600      20000            30    sample     False
# 18        200       8000            30    sample      True
# 19        200      10000            20    sample      True
# 20        300      10000            30    sample      True
# 21        200      10000            20    sample      True

# %%
datasets = {
    dataset_id: sc.read_h5ad(
        f"../../data/20_qc_norm_scrnaseq/01_qc_and_filtering/{dataset_id}/{dataset_id}.qc.h5ad"
    )
    for dataset_id in tqdm(dataset_table["id"])
}
# Out:
# 100%|██████████| 22/22 [00:34<00:00,  1.55s/it]

# %% [markdown]
# ### Dataset-specific filtering and metadata fixes

# %%
datasets["Adams_Kaminski_2020_COPD"].obs["origin"] = "normal"
datasets["Adams_Kaminski_2020_COPD"].obs["sex"] = "nan"
datasets["Adams_Kaminski_2020_COPD"] = datasets["Adams_Kaminski_2020_COPD"][
    datasets["Adams_Kaminski_2020_COPD"].obs["condition"] != "IPF", :
]
# Out:
# /home/sturm/.conda/envs/pircher-sc-integrate2/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
# No modifications necessary for Chen_Zhang

# %%
datasets["Goveia_Carmeliet_2020_NSCLC"] = datasets["Goveia_Carmeliet_2020_NSCLC"][
    datasets["Goveia_Carmeliet_2020_NSCLC"].obs["condition"] != "LLCC"
].copy()
datasets["Goveia_Carmeliet_2020_NSCLC"].obs["sex"] = "nan"

# %%
datasets["Guo_Zhang_2018_NSCLC"] = datasets["Guo_Zhang_2018_NSCLC"][
    datasets["Guo_Zhang_2018_NSCLC"].obs["tissue"] != "blood"
].copy()
datasets["Guo_Zhang_2018_NSCLC"] = normalize_by_gene_length(
    datasets["Guo_Zhang_2018_NSCLC"]
)
datasets["Guo_Zhang_2018_NSCLC"].obs["sex"] = "nan"

# %%
datasets["Habermann_Kropski_2020_pulmonary-fibrosis"].obs["sex"] = [
    {"M": "male", "F": "female", "Unknown": "nan"}[s]
    for s in datasets["Habermann_Kropski_2020_pulmonary-fibrosis"].obs["sex"]
]
datasets["Habermann_Kropski_2020_pulmonary-fibrosis"] = datasets[
    "Habermann_Kropski_2020_pulmonary-fibrosis"
][
    datasets["Habermann_Kropski_2020_pulmonary-fibrosis"].obs["condition"]
    == "healthy_control",
    :,
].copy()

# %%
# No modifications necessary for He_Fan

# %%
datasets["Maynard_Bivona_2020_NSCLC"] = normalize_by_gene_length(
    datasets["Maynard_Bivona_2020_NSCLC"]
)

# %%
datasets["Laughney_Massague_2020_NSCLC"].obs["sex"] = "nan"

# %%
datasets["Maier_Merad_2020_NSCLC"].obs["sex"] = "nan"

# %%
datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].obs["tissue"] = "lung"
datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].obs["origin"] = "normal"
datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].obs["condition"] = "healthy_control"
datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].obs["sex"] = "nan"
datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].X.data = np.rint(
    datasets["Madissoon_Meyer_2020_pulmonary-fibrosis"].X.data
)

# %%
datasets["Mayr_Schiller_2020_pulmonary-fibrosis"].obs["sex"] = "nan"
datasets["Mayr_Schiller_2020_pulmonary-fibrosis"] = datasets[
    "Mayr_Schiller_2020_pulmonary-fibrosis"
][
    datasets["Mayr_Schiller_2020_pulmonary-fibrosis"].obs["condition"]
    == "healthy_control",
    :,
]

# %%
datasets["Reyfman_Misharin_2018_pulmonary-fibrosis"].obs["sex"] = "nan"
datasets["Reyfman_Misharin_2018_pulmonary-fibrosis"] = datasets[
    "Reyfman_Misharin_2018_pulmonary-fibrosis"
][
    datasets["Reyfman_Misharin_2018_pulmonary-fibrosis"].obs["condition"]
    == "healthy_control",
    :,
]

# %%
datasets["Travaglini_Krasnow_2020_Lung_SS2"] = datasets[
    "Travaglini_Krasnow_2020_Lung_SS2"
][datasets["Travaglini_Krasnow_2020_Lung_SS2"].obs["tissue"] == "lung", :]

# %%
datasets["Zilionis_Klein_2019_NSCLC"] = datasets["Zilionis_Klein_2019_NSCLC"][
    datasets["Zilionis_Klein_2019_NSCLC"].obs["tissue"] == "lung", :
]
datasets["Zilionis_Klein_2019_NSCLC"].obs["sex"] = [
    {"M": "male", "F": "female", "Unknown": "nan"}[s]
    for s in datasets["Zilionis_Klein_2019_NSCLC"].obs["sex"]
]
# Out:
# Trying to set attribute `.obs` of view, copying.

# %% [markdown]
# ### make patients unique across datasets
#
# Except for the two Travaglini variants - they are the same patients profiled with different platforms

# %%
for dataset_id, adata in datasets.items():
    adata.obs["dataset"] = dataset_id
    adata.obs["patient"] = [
        f'{dataset.replace("_10x", "").replace("_SS2", "")}_{patient}'
        for dataset, patient in zip(adata.obs["dataset"], adata.obs["patient"])
    ]
    datasets[dataset_id] = adata
# Out:
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.
# Trying to set attribute `.obs` of view, copying.

# %% [markdown]
# ### Validate data

# %%
for dataset_id, adata in datasets.items():
    print(f"Validating {dataset_id}")
    sanitize_adata(adata)
    validate_adata(adata)
# Out:
# Validating Adams_Kaminski_2020_COPD
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# ... storing 'origin' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# ... storing 'dataset' as categorical
# Validating Chen_Zhang_2020_NSCLC
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# Validating Goveia_Carmeliet_2020_NSCLC
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# Validating Guo_Zhang_2018_NSCLC
# ... storing 'sample' as categorical
# ... storing 'sex' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# Validating Habermann_Kropski_2020_pulmonary-fibrosis
# Validating He_Fan_2021_LUAD
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'dataset' as categorical
# Validating Kim_Lee_2020_LUAD
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# Validating Lambrechts_2018_LUAD_6149v1
# Validating Lambrechts_2018_LUAD_6149v2
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# Validating Lambrechts_2018_LUAD_6653
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# Validating Laughney_Massague_2020_NSCLC
# Validating Madissoon_Meyer_2020_pulmonary-fibrosis
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# ... storing 'tissue' as categorical
# ... storing 'origin' as categorical
# ... storing 'condition' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# Validating Maier_Merad_2020_NSCLC
# Validating Maynard_Bivona_2020_NSCLC
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sex' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# Validating Mayr_Schiller_2020_pulmonary-fibrosis
# Validating Reyfman_Misharin_2018_pulmonary-fibrosis
# ... storing 'patient' as categorical
# ... storing 'sex' as categorical
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# Validating Travaglini_Krasnow_2020_Lung_10x
# Validating Travaglini_Krasnow_2020_Lung_SS2
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# Validating UKIM-V
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'patient' as categorical
# ... storing 'sample' as categorical
# Validating Vieira_Teichmann_2019_asthma
# Validating Wu_Zhou_2021_NSCLC
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sample' as categorical
# ... storing 'sex' as categorical
# ... storing 'patient' as categorical
# ... storing 'dataset' as categorical
# Validating Zilionis_Klein_2019_NSCLC

# %% [markdown]
# ## Gene identifier remapping

# %%
datasets_remapped = process_map(remap_gene_symbols, datasets.values(), max_workers=32)
for dataset_id, dataset in zip(datasets.keys(), datasets_remapped):
    datasets[dataset_id] = dataset
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# querying 1-1000...done.
# querying 1-1000...querying 1001-2000...querying 1-1000...querying 1-1000...done.
# querying 1001-2000...done.
# done.
# querying 1-1000...done.
# querying 1001-2000...querying 2001-3000...querying 1001-2000...done.
# done.
# querying 2001-3000...done.
# querying 1001-2000...done.
# done.
# querying 2001-3000...done.
# querying 2001-3000...querying 3001-4000...done.
# querying 3001-4000...querying 2001-3000...done.
# done.
# done.
# querying 3001-4000...querying 4001-5000...querying 3001-4000...done.
# done.
# querying 4001-5000...querying 3001-4000...querying 1-1000...done.
# done.
# done.
# done.
# querying 4001-5000...done.
# done.
# querying 5001-6000...querying 4001-5000...querying 5001-6000...querying 1001-2000...querying 4001-5000...querying 1-1000...
# done.querying 1-1000...querying 5001-6000...querying 1-1000...done.
# done.
# done.
# done.
# done.
# querying 1-1000...querying 6001-7000...querying 6001-7000...querying 5001-6000...querying 5001-6000...querying 2001-3000...done.
# done.
# querying 1-1000...done.
# done.
# querying 1001-2000...querying 1001-2000...querying 1001-2000...done.
# querying 6001-7000...done.
# querying 6001-7000...done.
# querying 1-1000...
# querying 7001-8000...querying 1-1000...querying 6001-7000...done.done.
# done.
# done.
# querying 1001-2000...querying 7001-8000...querying 3001-4000...querying 7001-8000...
# querying 1-1000...done.
# done.
# querying 1-1000...done.querying 8001-9000...done.
# done.
# querying 7001-8000...done.
# querying 2001-3000...querying 1001-2000...querying 1001-2000...querying 4001-5000...querying 1-1000...done.
# done.
# done.
# querying 1-1000...done.
# done.
# done.
# querying 2001-3000...done.
# querying 2001-3000...querying 8001-9000...querying 8001-9000...querying 2001-3000...querying 7001-8000...querying 9001-10000...done.
# querying 1-1000...querying 1001-2000...querying 1-1000...querying 1-1000...done.
# done.
# querying 8001-9000...querying 1001-2000...done.
# done.
# done.
# querying 1001-2000...querying 1001-2000...querying 1001-2000...done.done.
#
# done.done.
#
# done.
# done.
# done.
# done.
# done.
# querying 1-1000...querying 1-1000...done.done.
#
# querying 3001-4000...querying 2001-3000...done.done.
#
# done.
# querying 1001-2000...querying 5001-6000...querying 3001-4000...querying 2001-3000...querying 2001-3000...querying 9001-10000...querying 1001-2000...querying 2001-3000...querying 3001-4000...querying 9001-10000...querying 8001-9000...querying 3001-4000...done.done.done.
#
#
# done.
# done.done.
#
# done.
# done.
# querying 2001-3000...querying 1001-2000...querying 1001-2000...querying 10001-11000...querying 2001-3000...querying 2001-3000...querying 9001-10000...querying 1001-2000...done.done.
#
# done.
# querying 4001-5000...querying 4001-5000...querying 10001-11000...done.
# done.
# done.
# done.
# done.done.
#
# done.
# querying 3001-4000...querying 3001-4000...querying 2001-3000...querying 3001-4000...querying 4001-5000...querying 9001-10000...done.
# querying 4001-5000...done.
# done.
# querying 6001-7000...querying 2001-3000...querying 3001-4000...done.
# done.
# done.done.
#
# done.
# done.
# done.
# querying 2001-3000...done.
# querying 2001-3000...querying 3001-4000...querying 11001-12000...querying 3001-4000...done.
# querying 3001-4000...done.
# querying 5001-6000...querying 4001-5000...done.done.
#
# querying 4001-5000...querying 3001-4000...querying 10001-11000...querying 11001-12000...done.
# done.done.
#
# querying 4001-5000...querying 10001-11000...querying 4001-5000...done.
# done.
# done.
# done.
# done.
# done.
# querying 5001-6000...querying 5001-6000...querying 5001-6000...querying 2001-3000...querying 4001-5000...querying 10001-11000...done.
# done.
# done.
# querying 5001-6000...done.
# querying 3001-4000...querying 3001-4000...querying 4001-5000...done.
# done.
# done.
# done.
# done.
# done.
# querying 4001-5000...done.
# querying 11001-12000...querying 7001-8000...querying 5001-6000...querying 5001-6000...querying 12001-13000...done.
# querying 6001-7000...done.
# done.
# querying 4001-5000...done.done.
#
# querying 4001-5000...querying 6001-7000...querying 6001-7000...querying 12001-13000...done.
# done.done.
#
# done.
# done.
# done.
# done.
# querying 3001-4000...querying 6001-7000...querying 11001-12000...querying 8001-9000...querying 5001-6000...querying 11001-12000...done.
# done.
# done.
# querying 12001-13000...done.
# done.
# querying 13001-14000...done.
# querying 5001-6000...done.done.
#
# querying 5001-6000...done.
# done.
# querying 13001-14000...querying 6001-7000...querying 5001-6000...querying 3001-4000...querying 4001-5000...querying 4001-5000...querying 7001-8000...done.
# done.
# done.
# done.
# querying 6001-7000...querying 6001-7000...querying 13001-14000...querying 7001-8000...done.
# done.
# done.
# done.
# done.
# done.
# done.
# done.
# querying 12001-13000...done.
# done.
# querying 4001-5000...done.
# querying 5001-6000...querying 12001-13000...querying 7001-8000...querying 8001-9000...querying 7001-8000...querying 6001-7000...querying 5001-6000...querying 6001-7000...querying 7001-8000...done.
# done.
# done.
# querying 14001-15000...done.done.
#
# querying 5001-6000...done.
# done.
# querying 14001-15000...querying 14001-15000...querying 7001-8000...done.
# querying 8001-9000...querying 13001-14000...done.
# done.
# done.
# querying 6001-7000...querying 15001-16000...querying 13001-14000...querying 6001-7000...done.
# done.
# done.
# done.
# querying 9001-10000...done.
# querying 7001-8000...querying 5001-6000...done.
# querying 6001-7000...done.
# querying 8001-9000...done.
# done.
# querying 7001-8000...done.
# done.
# querying 7001-8000...done.
# querying 9001-10000...querying 16001-17000...done.
# done.
# querying 6001-7000...querying 8001-9000...querying 8001-9000...done.
# done.
# querying 9001-10000...querying 14001-15000...done.
# done.
# querying 5001-6000...querying 6001-7000...querying 8001-9000...querying 8001-9000...done.
# done.
# done.
# querying 7001-8000...querying 6001-7000...querying 15001-16000...done.
# done.
# done.
# done.
# querying 9001-10000...querying 7001-8000...done.
# done.
# done.
# querying 7001-8000...querying 14001-15000...querying 9001-10000...querying 8001-9000...querying 9001-10000...done.
# done.
# done.
# querying 9001-10000...done.
# querying 15001-16000...querying 10001-11000...done.
# querying 8001-9000...querying 10001-11000...done.
# done.
# done.
# done.
# done.
# done.
# querying 16001-17000...querying 15001-16000...querying 16001-17000...querying 7001-8000...querying 9001-10000...querying 10001-11000...done.
# done.
# done.
# done.
# done.done.
# done.
#
# done.
# done.
# querying 6001-7000...querying 9001-10000...querying 8001-9000...querying 7001-8000...querying 11001-12000...querying 15001-16000...querying 7001-8000...querying 10001-11000...done.
# done.
# querying 11001-12000...done.
# done.
# querying 17001-18000...querying 10001-11000...querying 17001-18000...querying 8001-9000...done.done.done.
#
#
# done.
# querying 10001-11000...querying 10001-11000...querying 11001-12000...done.
# done.
# done.
# done.
# querying 16001-17000...done.
# querying 8001-9000...querying 9001-10000...done.
# done.
# querying 9001-10000...querying 12001-13000...done.
# querying 18001-19000...querying 10001-11000...querying 8001-9000...querying 12001-13000...done.
# done.
# done.
# querying 11001-12000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# done.
# querying 8001-9000...querying 8001-9000...querying 16001-17000...querying 10001-11000...done.
# done.
# done.
# done.
# done.
# done.
# done.
# querying 19001-20000...querying 12001-13000...done.
# done.
# done.
# querying 9001-10000...querying 17001-18000...querying 11001-12000...querying 12001-13000...querying 10001-11000...done.
# querying 10001-11000...querying 19001-20000...querying 13001-14000...querying 7001-8000...done.
# done.
# done.
# done.
# querying 18001-18450...done.
# querying 10001-11000...querying 9001-10000...querying 13001-14000...querying 11001-12000...done.
# done.done.done.
#
#
# done.
# done.
# done.
# querying 11001-12000...querying 20001-21000...querying 14001-15000...querying 9001-10000...querying 18001-19000...querying 13001-14000...querying 8001-9000...done.
# done.done.
#
# done.
# Finished.
# 4140 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('AAK1', 2), ('AARSD1', 4), ('ABCA9', 2), ('ABCB10', 10), ('
# 2129 input query terms found no hit:
# done.
# 	['ABC12-49244600F4.4', 'AC000403.4', 'AC002076.10', 'AC002116.7', 'AC002117.1', 'AC002310.12', 'AC00
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 17641/18450 genes remapped.
# querying 11001-12000...querying 9001-10000...querying 11001-12000...done.done.
#
# querying 9001-10000...done.done.done.
#
#
# querying 14001-15000...querying 20001-21000...done.
# querying 11001-12000...querying 10001-11000...querying 13001-14000...done.
# done.
# done.
# querying 11001-12000...done.
# done.
# done.
# querying 12001-13000...done.
# done.
# querying 9001-10000...querying 15001-16000...querying 19001-20000...querying 21001-22000...querying 14001-15000...querying 10001-11000...done.
# querying 12001-13000...querying 15001-16000...done.
# done.
# done.
# done.
# done.
# done.
# querying 17001-18000...querying 12001-13000...querying 13001-14000...done.
# querying 14001-15000...querying 10001-11000...querying 12001-13000...done.
# done.
# querying 21001-22000...querying 12001-13000...querying 10001-11000...done.
# done.
# done.
# done.
# done.
# done.
# querying 11001-12000...querying 20001-21000...querying 11001-12000...done.
# done.
# done.
# done.
# querying 12001-13000...done.
# querying 16001-17000...querying 15001-16000...done.
# querying 16001-17000...querying 11001-12000...querying 22001-23000...done.
# querying 18001-19000...done.
# querying 13001-14000...querying 13001-14000...done.done.
#
# done.
# querying 13001-14000...querying 13001-14000...done.
# querying 12001-13000...querying 11001-12000...querying 14001-15000...done.
# done.
# querying 22001-23000...done.
# querying 12001-13000...done.
# done.
# done.
# querying 10001-11000...done.
# querying 15001-16000...done.
# querying 23001-24000...querying 21001-22000...querying 16001-17000...done.
# querying 14001-15000...querying 17001-18000...done.
# done.
# querying 14001-15000...done.
# done.
# done.
# done.
# querying 12001-13000...done.
# querying 23001-24000...querying 17001-18000...querying 11001-12000...done.
# querying 13001-14000...querying 14001-15000...querying 13001-14000...done.
# done.
# done.
# done.
# querying 19001-20000...done.
# querying 13001-14000...done.
# querying 15001-16000...querying 24001-25000...querying 18001-19000...done.
# done.
# querying 15001-16000...querying 15001-16000...done.
# done.
# querying 14001-15000...querying 12001-13000...querying 22001-23000...done.
# done.
# querying 11001-12000...done.
# done.
# done.
# querying 12001-13000...querying 16001-17000...querying 17001-18000...querying 16001-17000...querying 19001-20000...done.done.
#
# done.
# done.
# done.
# done.
# querying 23001-24000...querying 14001-15000...querying 14001-15000...querying 18001-19000...querying 16001-17000...done.done.
#
# querying 13001-14000...done.
# done.
# querying 12001-13000...querying 16001-17000...done.
# querying 15001-16000...querying 18001-19000...querying 12001-13000...done.
# done.
# done.
# done.
# querying 20001-21000...done.
# done.
# querying 17001-18000...done.
# done.
# querying 13001-14000...querying 13001-14000...done.
# done.
# querying 14001-15000...querying 17001-18000...querying 14001-15000...querying 24001-25000...querying 19001-20000...querying 20001-21000...done.
# querying 13001-14000...done.done.
#
# done.done.
# done.
# done.
# done.
# done.
#
# querying 25001-26000...querying 15001-16000...done.
# done.
# querying 13001-14000...querying 15001-16000...querying 17001-18000...querying 14001-15000...querying 15001-16000...querying 17001-18000...done.
# querying 21001-22000...querying 25001-26000...querying 15001-16000...done.
# done.
# done.
# done.
# querying 18001-19000...querying 24001-25000...querying 18001-19000...done.
# done.
# done.
# querying 14001-15000...querying 16001-17000...done.
# querying 21001-22000...querying 18001-19000...done.
# done.
# done.
# querying 14001-15000...querying 22001-23000...done.
# done.
# querying 14001-15000...querying 26001-27000...done.
# done.
# done.done.
#
# querying 26001-27000...querying 19001-20000...querying 15001-16000...querying 16001-17000...done.
# querying 22001-23000...querying 25001-26000...done.
# done.
# done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# done.
# querying 16001-17000...querying 20001-21000...done.
# querying 16001-17000...done.
# querying 23001-24000...querying 27001-27717...querying 15001-16000...done.done.
#
# querying 27001-28000...done.done.
# querying 15001-16000...
# querying 18001-19000...done.
# done.
# querying 16001-17000...querying 15001-16000...done.
# querying 19001-20000...Finished.
# 5248 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('SLC35E2', 2), ('PRKCZ', 2), ('SKI', 5),
# 7463 input query terms found no hit:
# 	['RP11-34P13.3', 'RP11-34P13.7', 'RP11-34P13.8', 'RP11-34P13.14', 'FO538757.3', 'FO538757.2', 'AP006
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# querying 24001-25000...The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.done.
#
# Remapping complete! 26661/27717 genes remapped.
# done.
# done.
# done.
# done.
# done.
# querying 19001-20000...querying 20001-21000...querying 26001-27000...querying 28001-29000...querying 17001-18000...querying 23001-24000...done.
# done.
# done.
# querying 17001-18000...querying 21001-22000...querying 16001-17000...done.
# done.
# done.
# done.
# querying 17001-18000...querying 16001-17000...done.
# done.
# done.
# querying 19001-20000...querying 20001-21000...done.
# querying 20001-21000...querying 17001-18000...done.
# done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 16001-16322...querying 29001-30000...done.
# querying 25001-26000...querying 21001-22000...done.
# done.
# done.
# querying 22001-23000...done.
# done.
# querying 24001-25000...done.
# querying 18001-19000...querying 18001-19000...done.
# querying 17001-18000...done.
# done.
# querying 20001-21000...done.
# querying 30001-31000...querying 17001-18000...done.
# querying 17001-18000...querying 27001-28000...querying 18001-19000...querying 19001-20000...done.
# done.
# done.
# done.
# querying 26001-26359...querying 23001-24000...done.
# querying 18001-19000...Finished.
# 3633 input query terms found dup hits:
# 	[('A2M', 5), ('AAK1', 2), ('AARSD1', 4), ('ABCA9', 2), ('ABCB10', 10), ('ABCC2', 2), ('ABCC3', 2), (
# 1818 input query terms found no hit:
# 	['AC002044.4', 'AC002064.4', 'AC002117.1', 'AC002310.12', 'AC002310.7', 'AC002398.11', 'AC002398.12'
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['MIR1254-1', 'hsa-mir-4259']
# querying 1-2...querying 28001-28863...done.
# done.done.done.
# done.done.
#
# done.
#
#
# done.done.
#
# Finished.
# 5401 input query terms found dup hits:
# 	[('TTLL10', 2), ('LINC01786', 2), ('DVL1', 2), ('MRPL20', 4), ('LINC01770', 2), ('SSU72', 10), ('PRK
# 6381 input query terms found no hit:
# 	['AL627309.1', 'AL627309.5', 'AP006222.2', 'AL645608.2', 'AL645608.4', 'AL645608.7', 'AL390719.3', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# querying 19001-19681...Re-querying with the following entries: querying 25001-26000...querying 19001-20000...
# querying 21001-22000...querying 31001-32000...['CYB561D2-1', 'GGT1-1', 'HSPA14-1', 'LINC01238-1', 'TBCE-1']querying 21001-21595...
# querying 16001-17000...querying 1-5...querying 18001-19000...done.
# done.done.
#
# done.done.done.done.
#
#
#
# done.
# done.
# Finished.querying 22001-23000...
# querying 19001-20000...1 input query terms found dup hits:
# 	[('hsa-mir', 2)]
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 15327/16322 genes remapped.
# querying 18001-19000...querying 18001-19000...querying 20001-21000...querying 19001-19201...querying 24001-25000...done.
# querying 21001-22000...done.
# done.
# Finished.
# 5720 input query terms found dup hits:
# 	[('TTLL10', 2), ('LINC01786', 2), ('DVL1', 2), ('MRPL20', 4), ('LINC01770', 2), ('SSU72', 10), ('PRK
# 7916 input query terms found no hit:
# 	['AL627309.1', 'AL627309.5', 'AP006222.2', 'AC114498.1', 'AL645608.6', 'AL645608.2', 'AL645608.4', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['ARMCX5-GPRASP2-1', 'CYB561D2-1', 'GGT1-1', 'GOLGA8M-1', 'HSPA14-1', 'LINC01238-1', 'TBCE-1']
# querying 1-7...done.
# done.
# done.
# querying 19001-20000...Finished.
# 4674 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('AADACL2', 4), ('AAK1', 2), ('AARSD1', 4), ('ABCA9', 2), ('
# 3148 input query terms found no hit:
# 	['AB015752.3', 'ABC12-49244600F4.4', 'ABC13-47488600E17.1', 'ABC13-47656900H15.1', 'ABC7-481722F1.2'
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 20511/21595 genes remapped.
# querying 26001-27000...querying 22001-23000...Finished.
# Remapping complete! 26026/26359 genes remapped.
# done.done.
#
# done.
# done.
# done.done.done.
#
#
# done.
# done.
# done.done.
#
# done.
# Finished.Finished.
#
# 1 input query terms found dup hits:querying 20001-21000...
# 	[('ARMCX5-GPRASP2', 2)]
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# 4473 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('PRKCZ', 2), ('SKI', 5), ('TNFRSF14-AS1'
# 2405 input query terms found no hit:
# 	['AL627309.5', 'AL645608.7', 'AL390719.2', 'AL391244.2', 'AL645728.1', 'AL691432.4', 'AL691432.2', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 28510/28863 genes remapped.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['CYB561D2-1', 'HSPA14-1', 'TBCE-1']
# querying 1-3...Finished.
# querying 19001-20000...querying 19001-20000...querying 19001-20000...querying 25001-25034...4166 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('SLC35E2', 2), ('PRKCZ', 2), ('SKI', 5),
# 3218 input query terms found no hit:
# 	['RP11-34P13.7', 'FO538757.2', 'AP006222.2', 'RP4-669L17.10', 'RP5-857K21.4', 'RP11-206L10.9', 'RP11
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 18823/19681 genes remapped.
# querying 20001-21000...done.done.
#
# querying 32001-33000...querying 23001-24000...done.
# querying 17001-18000...done.
# querying 27001-28000...Finished.
# 4877 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('SLC35E2', 2), ('PRKCZ', 2), ('SKI', 5),
# 5906 input query terms found no hit:
# 	['RP11-34P13.7', 'RP11-34P13.8', 'FO538757.3', 'FO538757.2', 'AP006222.2', 'RP4-669L17.2', 'RP4-669L
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# done.
# Finished.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['ATRIP-1', 'C1QTNF9B-AS1-1', 'CCDC7-1', 'CFAP99-1', 'CYB561D2-1', 'ECSCR-1', 'IGHV2-70-1', 'LINC01422-1', 'LINC01481-1', 'PGM5-AS1-1', 'RAET1E-AS1-1', 'SERPINA3-1', 'TIMM10B-1', 'TMEM256-PLSCR3-1']
# querying 1-14...Remapping complete! 18922/19201 genes remapped.
# querying 21001-22000...querying 22001-23000...done.
# done.
# done.
# done.done.done.
# done.
#
#
# done.
# done.
# Finished.
# 4 input query terms found dup hits:
# 	[('ATRIP', 2), ('IGHV2-70', 3), ('LINC01422', 2), ('TMEM256-PLSCR3', 3)]
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 24006/25034 genes remapped.
# querying 20001-21000...querying 23001-24000...done.
# done.done.
#
# querying 24001-25000...querying 21001-22000...querying 20001-21000...querying 20001-21000...querying 20001-21000...querying 21001-22000...done.
# done.
# querying 18001-19000...querying 33001-34000...querying 28001-29000...querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 22001-23000...done.
# done.
# querying 21001-22000...querying 25001-26000...querying 19001-20000...done.
# done.
# done.
# done.
# done.
# done.
# querying 21001-22000...done.
# done.
# querying 25001-26000...querying 24001-25000...querying 29001-30000...querying 21001-22000...querying 34001-35000...querying 22001-23000...querying 23001-24000...done.
# done.
# querying 22001-23000...querying 20001-20926...done.
# done.
# done.
# done.
# querying 25001-26000...done.
# done.
# querying 23001-24000...done.
# done.
# querying 30001-31000...done.
# querying 24001-25000...querying 26001-27000...done.
# done.
# querying 22001-23000...querying 26001-26833...done.
# querying 22001-23000...Finished.
# 4975 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('MMP23A', 3), ('SLC35E2', 2), ('PRKCZ',
# 565 input query terms found no hit:
# 	['MIR6723', 'LOC100133331', 'LOC100130417', 'LOC148413', 'LOC102724312', 'LOC115110', 'LOC102724450'
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['MIR1254-1']
# querying 1-1...querying 23001-24000...querying 35001-36000...done.
# done.
# done.
# querying 21001-22000...done.
# querying 26001-27000...querying 23001-24000...done.
# done.
# Finished.
# Remapping complete! 19815/20926 genes remapped.
# querying 31001-32000...querying 24001-25000...querying 27001-27613...done.
# done.
# done.
# done.
# done.
# done.
# done.
# querying 23001-24000...Finished.
# querying 25001-26000...5462 input query terms found dup hits:
# 	[('TTLL10', 2), ('LINC01786', 2), ('DVL1', 2), ('MRPL20', 4), ('LINC01770', 2), ('SSU72', 10), ('PRK
# 6643 input query terms found no hit:
# 	['AL627309.1', 'AL627309.5', 'AP006222.2', 'AL732372.1', 'AL645608.2', 'AL645608.4', 'AL645608.7', 'querying 23001-24000...
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`. querying 22001-23000...
# Re-querying with the following entries:
# ['CYB561D2-1', 'GGT1-1', 'HSPA14-1', 'LINC01238-1', 'TBCE-1']
# querying 1-5...done.
# querying 24001-25000...querying 36001-37000...done.
# querying 27001-28000...done.
# done.
# Finished.
# 5138 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('AADACL2', 4), ('AAK1', 2), ('AARSD1', 4), ('ABCA9', 2), ('
# 7408 input query terms found no hit:
# 	['AB015752.3', 'AB019440.50', 'ABC12-49244600F4.4', 'ABC7-42404400C24.1', 'AC000032.2', 'AC000036.4'
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 26549/27613 genes remapped.
# Finished.
# querying 32001-33000...Remapping complete! 26492/26833 genes remapped.
# done.done.done.
#
#
# done.
# done.done.
# done.
#
# done.
# querying 24001-25000...querying 26001-27000...querying 25001-26000...querying 24001-25000...querying 24001-25000...querying 23001-24000...querying 25001-26000...querying 37001-38000...done.done.
#
# querying 33001-34000...querying 28001-29000...done.
# done.
# done.
# done.
# done.
# done.
# querying 25001-26000...done.
# done.
# querying 27001-28000...querying 26001-26636...querying 38001-39000...querying 24001-25000...querying 26001-26993...done.
# querying 25001-26000...querying 25001-26000...querying 29001-30000...done.
# done.
# done.
# querying 28001-29000...done.
# querying 34001-35000...querying 26001-27000...done.
# done.
# querying 26001-27000...done.
# done.
# done.
# querying 25001-25740...querying 26001-27000...querying 30001-31000...querying 39001-40000...done.
# done.
# Finished.
# 5491 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('A2ML1-AS1', 2), ('AADACL2', 4), ('AADACL2-AS1', 3), ('AAK1
# 5971 input query terms found no hit:
# 	['AC000032.1', 'AC000036.1', 'AC000061.1', 'AC000068.1', 'AC000068.2', 'AC000068.3', 'AC000403.1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 26171/26636 genes remapped.
# done.
# querying 29001-30000...querying 35001-36000...done.
# done.
# done.
# Finished.
# 5460 input query terms found dup hits:
# 	[('TTLL10', 2), ('LINC01786', 2), ('DVL1', 2), ('MRPL20', 4), ('LINC01770', 2), ('SSU72', 10), ('PRK
# 6796 input query terms found no hit:
# 	['AL627309.1', 'AL627309.5', 'AP006222.2', 'AL669831.2', 'AL645608.6', 'AL645608.2', 'AL645608.4', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# done.
# done.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['CYB561D2-1', 'GGT1-1', 'HSPA14-1', 'LINC01238-1', 'TBCE-1']
# querying 1-5...done.
# done.
# querying 27001-28000...querying 27001-28000...Finished.
# 4925 input query terms found dup hits:
# 	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('SSU72', 10), ('SLC35E2', 2), ('PRKCZ', 2), ('SKI', 5),
# 6359 input query terms found no hit:
# 	['RP11-34P13.7', 'RP11-34P13.8', 'FO538757.3', 'FO538757.2', 'AP006222.2', 'RP4-669L17.10', 'RP5-857
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# querying 31001-32000...The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['ATRIP-1', 'BLOC1S5-1', 'C1QTNF9B-AS1-1', 'CCDC7-1', 'CFAP99-1', 'CYB561D2-1', 'ECSCR-1', 'IGHV2-70-1', 'LINC00864-1', 'LINC01297-1', 'LINC01422-1', 'LINC01481-1', 'PGM5-AS1-1', 'RAET1E-AS1-1', 'SERPINA3-1', 'TIMM10B-1', 'TMEM256-PLSCR3-1']
# querying 1-17...querying 27001-28000...querying 40001-41000...done.
# Finished.
# Remapping complete! 26654/26993 genes remapped.
# done.
# done.
# querying 36001-37000...querying 30001-31000...Finished.
# 6 input query terms found dup hits:
# 	[('ATRIP', 2), ('BLOC1S5', 5), ('IGHV2-70', 3), ('LINC01297', 3), ('LINC01422', 2), ('TMEM256-PLSCR3
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 24707/25740 genes remapped.
# done.
# done.
# done.
# querying 28001-29000...querying 28001-29000...done.done.
#
# done.
# done.
# querying 32001-33000...querying 41001-42000...querying 28001-29000...querying 37001-38000...querying 31001-31399...done.
# done.
# done.
# done.
# querying 29001-29146...done.
# done.
# done.
# done.
# querying 29001-30000...querying 33001-34000...Finished.
# 7237 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('AAK1', 2), ('AARSD1', 4), ('ABCA9', 2), ('ABCB10', 10), ('ABCC2', 2), ('
# 9253 input query terms found no hit:
# 	['AC000068.10', 'AC000068.5', 'AC000068.9', 'AC002044.4', 'AC002064.5', 'AC002066.1', 'AC002116.7',
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['ERCC-00019', 'ERCC-00024', 'ERCC-00028', 'ERCC-00034', 'ERCC-00083', 'ERCC-00086', 'ERCC-00095', 'ERCC-00096', 'ERCC-00104', 'ERCC-00137', 'ERCC-00138', 'ERCC-00150', 'ERCC-00165', 'ERCC-00168', 'ERCC-00171', 'MIR1254-1', 'hsa-mir-150', 'snoU2-30']
# querying 1-18...querying 38001-39000...querying 29001-30000...querying 42001-42665...Finished.
# 7240 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('AADACL2', 4), ('AADACL2-AS1', 3), ('AAK1', 2), ('AARSD1',
# 7101 input query terms found no hit:
# 	['ABBA01000935.2', 'AC000032.1', 'AC000061.1', 'AC000067.1', 'AC000068.1', 'AC000068.2', 'AC000077.1
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# done.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['MIR1254-1']
# querying 1-1...done.
# done.
# Finished.
# 2 input query terms found dup hits:
# 	[('ERCC', 135), ('hsa-mir', 2)]
# 1 input query terms found no hit:
# 	['snoU2']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 30017/31399 genes remapped.
# done.
# Finished.
# Remapping complete! 28512/29146 genes remapped.
# querying 30001-31000...done.
# done.
# querying 39001-40000...done.
# querying 34001-35000...Finished.
# 11879 input query terms found dup hits:
# 	[('SCYL3', 2), ('SEMA3F', 2), ('CFTR', 10), ('CYP51A1', 2), ('RAD52', 4), ('MYH16', 2), ('LAP3', 2),
# 13832 input query terms found no hit:
# 	['ENSG00000036549', 'ENSG00000100101', 'ENSG00000111780', 'ENSG00000111788', 'ENSG00000115934', 'ENS
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# done.
# querying 30001-31000...The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['MIR3687-2']
# querying 1-1...done.
# done.
# querying 31001-32000...done.
# Finished.
# 1 input query terms found no hit:
# querying 40001-41000...	['MIR3687']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 42057/42665 genes remapped.
# querying 31001-32000...done.
# done.
# querying 35001-36000...querying 32001-33000...done.
# querying 41001-42000...done.done.
#
# done.
# querying 33001-34000...querying 32001-33000...querying 36001-37000...done.
# querying 42001-43000...done.
# done.
# done.
# querying 37001-38000...querying 33001-34000...querying 34001-35000...done.
# querying 43001-44000...done.
# done.
# done.
# querying 38001-39000...done.
# querying 34001-35000...querying 35001-36000...querying 44001-45000...done.
# querying 39001-40000...done.
# done.
# querying 45001-46000...done.
# done.
# querying 35001-36000...querying 36001-36900...querying 40001-41000...done.
# done.
# querying 46001-47000...done.
# querying 36001-37000...done.
# Finished.
# 7492 input query terms found dup hits:
# 	[('5S_rRNA', 10), ('5_8S_rRNA', 9), ('7SK', 10), ('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('A2ML1-AS1'
# 11979 input query terms found no hit:
# 	['AB015752.1', 'AC000032.1', 'AC000035.1', 'AC000036.1', 'AC000058.1', 'AC000061.1', 'AC000067.1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['Clostridiales-1', 'MIR1254-1', 'hsa-mir-3119-1', 'hsa-mir-3158-1', 'hsa-mir-548d-2', 'snoMBII-202', 'snoU2-30']
# querying 1-7...querying 41001-42000...done.
# done.
# done.
# Finished.
# 6 input query terms found no hit:
# 	['Clostridiales', 'hsa-mir-3119', 'hsa-mir-3158', 'hsa-mir-548d', 'snoMBII', 'snoU2']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 36172/36900 genes remapped.
# querying 47001-48000...querying 37001-38000...done.
# done.
# querying 42001-43000...querying 48001-48353...done.
# done.
# querying 38001-39000...done.
# Finished.
# 13805 input query terms found dup hits:
# 	[('PARTICL', 2), ('H3C2', 10), ('CCDC15-DT', 2), ('LINC02717', 2), ('FAM245B', 2), ('LINC02838', 2),
# 17125 input query terms found no hit:
# 	['AL645933.5', 'AC010184.1', 'AC023296.1', 'AL117334.2', 'AL357079.3', 'AL442063.1', 'AL360015.1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 48095/48353 genes remapped.
# querying 43001-44000...done.
# querying 39001-40000...done.
# querying 44001-45000...done.
# querying 40001-41000...done.
# querying 45001-46000...done.
# done.
# querying 46001-46813...querying 41001-42000...done.
# done.
# Finished.
# 13805 input query terms found dup hits:
# 	[('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('A2ML1-AS2', 2), ('AADACL2', 4), ('AADACL2-AS1', 3), ('AAK1
# 15107 input query terms found no hit:
# 	['AB015752.1', 'AC000032.1', 'AC000036.1', 'AC000058.1', 'AC000061.1', 'AC000067.1', 'AC000068.1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# ['MIR1254-1', 'MIR7641-1']
# querying 1-2...querying 42001-43000...done.
# Finished.
# 1 input query terms found no hit:
# 	['MIR7641']
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# Remapping complete! 46173/46813 genes remapped.
# done.
# querying 43001-44000...done.
# querying 44001-45000...done.
# querying 45001-46000...done.
# querying 46001-47000...done.
# querying 47001-48000...done.
# querying 48001-49000...done.
# querying 49001-50000...done.
# querying 50001-51000...done.
# querying 51001-52000...done.
# querying 52001-53000...done.
# querying 53001-54000...done.
# querying 54001-55000...done.
# querying 55001-55556...done.
# Finished.
# 16414 input query terms found dup hits:
# 	[('PARTICL', 2), ('H3C2', 10), ('CCDC15-DT', 2), ('LINC02717', 2), ('FAM245B', 2), ('LINC02838', 2),
# 21042 input query terms found no hit:
# 	['AL645933.5', 'AC010184.1', 'AC023296.1', 'AL117334.2', 'AC107294.4', 'AL357079.3', 'AL442063.1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# The following genes were not found and a '-\d+$' pattern was detected.
# They could potentially be affected by `.var_names_make_unique()`.
# Re-querying with the following entries:
# []
# Finished.
# Remapping complete! 55286/55556 genes remapped.

# %% [markdown]
# ### aggregate duplicate gene symbols
#
# TODO: take care of duplicate genes that were made unique with "var_names_make_unique"

# %%
for dataset_id, dataset in datasets.items():
    print(dataset_id)
    datasets[dataset_id] = aggregate_duplicate_gene_symbols(dataset)
# Out:
# Adams_Kaminski_2020_COPD
# 100%|██████████| 28/28 [00:00<00:00, 273.52it/s]
# /home/sturm/.conda/envs/pircher-sc-integrate2/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# Chen_Zhang_2020_NSCLC
# 100%|██████████| 19/19 [00:00<00:00, 364.23it/s]
# Goveia_Carmeliet_2020_NSCLC
# 100%|██████████| 22/22 [00:00<00:00, 501.60it/s]
# Guo_Zhang_2018_NSCLC
# 100%|██████████| 20/20 [00:00<00:00, 275.15it/s]
# Habermann_Kropski_2020_pulmonary-fibrosis
# 100%|██████████| 49/49 [00:00<00:00, 430.66it/s]
# He_Fan_2021_LUAD
# 100%|██████████| 47/47 [00:00<00:00, 416.33it/s]
# Kim_Lee_2020_LUAD
# 100%|██████████| 16/16 [00:00<00:00, 419.83it/s]
# Lambrechts_2018_LUAD_6149v1
# 100%|██████████| 9/9 [00:00<00:00, 548.78it/s]
# Lambrechts_2018_LUAD_6149v2
# 100%|██████████| 16/16 [00:00<00:00, 371.11it/s]
# Lambrechts_2018_LUAD_6653
# 100%|██████████| 14/14 [00:00<00:00, 443.97it/s]
# Laughney_Massague_2020_NSCLC
# 100%|██████████| 30/30 [00:00<00:00, 535.45it/s]
# Madissoon_Meyer_2020_pulmonary-fibrosis
# 100%|██████████| 53/53 [00:00<00:00, 465.87it/s]
# Maier_Merad_2020_NSCLC
# 100%|██████████| 27/27 [00:00<00:00, 592.00it/s]
# Maynard_Bivona_2020_NSCLC
# 100%|██████████| 20/20 [00:00<00:00, 244.16it/s]
# Mayr_Schiller_2020_pulmonary-fibrosis
# 100%|██████████| 785/785 [00:01<00:00, 419.48it/s]
# Reyfman_Misharin_2018_pulmonary-fibrosis
# 100%|██████████| 58/58 [00:00<00:00, 478.31it/s]
# 100%|██████████| 44/44 [00:00<00:00, 582.54it/s]
# Travaglini_Krasnow_2020_Lung_10x
# Travaglini_Krasnow_2020_Lung_SS2
# 100%|██████████| 35/35 [00:00<00:00, 293.14it/s]
# UKIM-V
# 100%|██████████| 15/15 [00:00<00:00, 455.59it/s]
# Vieira_Teichmann_2019_asthma
# 100%|██████████| 31/31 [00:00<00:00, 680.01it/s]
# Wu_Zhou_2021_NSCLC
# 100%|██████████| 21/21 [00:00<00:00, 404.72it/s]
# Zilionis_Klein_2019_NSCLC
# 100%|██████████| 32/32 [00:00<00:00, 372.62it/s]

# %% [markdown]
# ## add cell type annotation

# %%
for dataset in datasets.values():
    dataset.obs["cell_type"] = "unknown"

# %% [markdown]
# ## Export all

# %%
obs_all = pd.concat([x.obs for x in datasets.values()]).reset_index(drop=True)

# %%
obs_all = obs_all.loc[
    :,
    MANDATORY_COLS
    + [
        "accession",
        "sampleType",
        "platform",
        "age",
        "tobacco",
        "ethnicity",
        "processing_site",
        "Tissue origins",
        "histology",
        "smoking",
        "pathology",
        "EGFR",
        "tumor_stage",
        "geo_accession",
        "tissue_orig",
        "replicate",
        "race",
        "smoking_status",
        "driver_gene",
        "driver_mutation",
        "secondary_mutation",
        "Notes",
        "stage_at_diagnosis",
        "pathlogy_review",
        "biopsy_date",
        "sort_date",
        "biopsy_type",
        "biopsy_time_status",
        "early_treatment_status",
        "best_response_status",
        "biopsy_timing",
        "analysis",
        "treatment_history",
        "treatment_history_detail",
        "line_of_therapy",
        "treatment_type",
        "treatment",
        "percent_PFS_ref_values",
        "percent.PFS.reference.values",
        "infections",
        "early_bx_day",
        "treatment_start_date",
        "pfs_over_under",
        "pfs_day",
        "pfs_month",
        "date_of_death",
        "stageIII.IV_ca_dx_date",
        "ca_dx_OS",
        "region",
        "location",
        "label",
        "tumor_id",
        "tumor_type",
        "GEO_Sample",
        "biopsy_segment",
        "gsm",
        "characteristics_ch1.7.treatment received prior to surgery (1= treated; 0=untreated)",
    ],
].drop_duplicates().set_index("sample")

# %%
obs_all.to_excel("../../data/50_integrate_scrnaseq_data/51_merge_all/obs_all.xlsx")

# %%
merged_all = merge_datasets(datasets.values(), symbol_in_n_datasets=17)

# %%
merged_all.shape
# Out:
# (1124947, 17833)

# %%
merged_all.obs.drop_duplicates().reset_index(drop=True)
# Out:
#                               sample                              patient  \
# 0      Adams_Kaminski_2020_COPD_001C        Adams_Kaminski_2020_COPD_001C
# 1      Adams_Kaminski_2020_COPD_002C        Adams_Kaminski_2020_COPD_002C
# 2      Adams_Kaminski_2020_COPD_003C        Adams_Kaminski_2020_COPD_003C
# 3    Adams_Kaminski_2020_COPD_022C-a        Adams_Kaminski_2020_COPD_222C
# 4    Adams_Kaminski_2020_COPD_022C-b        Adams_Kaminski_2020_COPD_222C
# ..                               ...                                  ...
# 500   Zilionis_Klein_2019_NSCLC_p2t1  Zilionis_Klein_2019_NSCLC_patient_2
# 501   Zilionis_Klein_2019_NSCLC_p4t1  Zilionis_Klein_2019_NSCLC_patient_4
# 502   Zilionis_Klein_2019_NSCLC_p1t3  Zilionis_Klein_2019_NSCLC_patient_1
# 503   Zilionis_Klein_2019_NSCLC_p5t1  Zilionis_Klein_2019_NSCLC_patient_5
# 504   Zilionis_Klein_2019_NSCLC_p3t3  Zilionis_Klein_2019_NSCLC_patient_3
#
#     tissue         origin        condition                    dataset     sex  \
# 0     lung         normal  healthy_control   Adams_Kaminski_2020_COPD     nan
# 1     lung         normal  healthy_control   Adams_Kaminski_2020_COPD     nan
# 2     lung         normal  healthy_control   Adams_Kaminski_2020_COPD     nan
# 3     lung         normal  healthy_control   Adams_Kaminski_2020_COPD     nan
# 4     lung         normal  healthy_control   Adams_Kaminski_2020_COPD     nan
# ..     ...            ...              ...                        ...     ...
# 500   lung  tumor_primary             LSCC  Zilionis_Klein_2019_NSCLC  female
# 501   lung  tumor_primary             LUAD  Zilionis_Klein_2019_NSCLC    male
# 502   lung  tumor_primary             LSCC  Zilionis_Klein_2019_NSCLC    male
# 503   lung  tumor_primary             LUAD  Zilionis_Klein_2019_NSCLC  female
# 504   lung  tumor_primary             LUAD  Zilionis_Klein_2019_NSCLC  female
#
#     cell_type                                              batch
# 0     unknown  Adams_Kaminski_2020_COPD_Adams_Kaminski_2020_C...
# 1     unknown  Adams_Kaminski_2020_COPD_Adams_Kaminski_2020_C...
# 2     unknown  Adams_Kaminski_2020_COPD_Adams_Kaminski_2020_C...
# 3     unknown  Adams_Kaminski_2020_COPD_Adams_Kaminski_2020_C...
# 4     unknown  Adams_Kaminski_2020_COPD_Adams_Kaminski_2020_C...
# ..        ...                                                ...
# 500   unknown  Zilionis_Klein_2019_NSCLC_Zilionis_Klein_2019_...
# 501   unknown  Zilionis_Klein_2019_NSCLC_Zilionis_Klein_2019_...
# 502   unknown  Zilionis_Klein_2019_NSCLC_Zilionis_Klein_2019_...
# 503   unknown  Zilionis_Klein_2019_NSCLC_Zilionis_Klein_2019_...
# 504   unknown  Zilionis_Klein_2019_NSCLC_Zilionis_Klein_2019_...
#
# [505 rows x 9 columns]

# %%
merged_all.write_h5ad(
    "../../data/50_integrate_scrnaseq_data/51_merge_all/merged_all.h5ad"
)
# Out:
# ... storing 'sample' as categorical
# ... storing 'patient' as categorical
# ... storing 'tissue' as categorical
# ... storing 'origin' as categorical
# ... storing 'condition' as categorical
# ... storing 'dataset' as categorical
# ... storing 'sex' as categorical
# ... storing 'cell_type' as categorical
# ... storing 'batch' as categorical

# %% [markdown]
# ## Export for NSCLC heterogeneity
#  * only tumor samples (no controls, no metastases)
#  * all NSCLC subtypes

# %%
# datasets_nsclc_heterogeneity = dict()
# for dataset_id, dataset in datasets.items():
#     if "tumor_primary" in dataset.obs["origin"].values:
#         datasets_nsclc_heterogeneity[dataset_id] = dataset[
#             dataset.obs["origin"] == "tumor_primary", :
#         ].copy()
# del datasets_nsclc_heterogeneity["Pircher_batch1_NSCLC"]

# %%
# merged_nsclc_heterogeneity = merge_datasets(
#     datasets_nsclc_heterogeneity.values(), symbol_in_n_datasets=5
# )

# %%
# merged_nsclc_heterogeneity.shape

# %%
# merged_nsclc_heterogeneity.write_h5ad(
#     "../../data/50_integrate_scrnaseq_data/51_merge_all/merged_nsclc_heterogeneity.h5ad"
# )
